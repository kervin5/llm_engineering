# %% [markdown]
# # The Price is Right
#
# Today we build a more complex solution for estimating prices of goods.
#
# 1. Day 2.0 notebook: create a RAG database with our 400,000 training data
# 2. Day 2.1 notebook: visualize in 2D
# 3. Day 2.2 notebook: visualize in 3D
# 4. Day 2.3 notebook: build and test a RAG pipeline with GPT-4o-mini
# 5. Day 2.4 notebook: (a) bring back our Random Forest pricer (b) Create a Ensemble pricer that allows contributions from all the pricers
#
# Phew! That's a lot to get through in one day!
#
# ## PLEASE NOTE:
#
# We already have a very powerful product estimator with our proprietary, fine-tuned LLM. Most people would be very satisfied with that! The main reason we're adding these extra steps is to deepen your expertise with RAG and with Agentic workflows.
#
# ## Finishing off with Random Forests & Ensemble

# %%
# imports

import os
import re
import math
import json
from tqdm import tqdm
import random
from dotenv import load_dotenv
from huggingface_hub import login
import numpy as np
import pickle
from openai import OpenAI
from sentence_transformers import SentenceTransformer
from datasets import load_dataset
import chromadb
from items import Item
from testing import Tester
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import joblib

# %%
# CONSTANTS

QUESTION = "How much does this cost to the nearest dollar?\n\n"
DB = "products_vectorstore"

# %%
# environment

load_dotenv(override=True)
os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY', 'your-key-if-not-using-env')
os.environ['HF_TOKEN'] = os.getenv('HF_TOKEN', 'your-key-if-not-using-env')

# %%
# Load in the test pickle file:

with open('test.pkl', 'rb') as file:
    test = pickle.load(file)

# %%
client = chromadb.PersistentClient(path=DB)
collection = client.get_or_create_collection('products')

# %%
result = collection.get(include=['embeddings', 'documents', 'metadatas'])
vectors = np.array(result['embeddings'])
documents = result['documents']
prices = [metadata['price'] for metadata in result['metadatas']]

# %%
prices[0:5]  # Display the first 5 prices for verification
# Out:
# [226.95, 506.98, 405.0, 1.95, 246.93]

# %% [markdown]
# # Random Forest
#
# We will now train a Random Forest model.
#
# Can you spot the difference from what we did in Week 6? In week 6 we used the word2vec model to form vectors; this time we'll use the vectors we already have in Chroma, from the SentenceTransformer model.

# %%
# %load_ext cuml.accel
# Out:
# cuML: Accelerator installed.

# %%
import cuml
print("cuML version:", cuml.__version__)
# Out:
# cuML version: 25.06.00

# %%
loaded = "cuml.accel" in get_ipython().extension_manager.loaded
print("GPU acceleration active?", loaded)
# Out:
# GPU acceleration active? True

# %%
# This is a simple example of using cuml's RandomForestRegressor to fit a model on a large dataset.
# It will utilize the GPU for acceleration.
# This is not necessary for the main task, but demonstrates how to use cuml.

from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
import time

X, y = make_regression(n_samples=500_000, n_features=50)

start = time.time()
model = RandomForestRegressor(n_estimators=100)
model.fit(X, y)
print("Elapsed:", time.time() - start)
# Out:
# Elapsed: 2.6778266429901123

# %%
# This next line takes an hour on my M1 Mac!

rf_model = RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=-1)
rf_model.fit(vectors, prices)
# Out:
# RandomForestRegressor(n_jobs=-1, random_state=42)

# %%
# Save the model to a file

joblib.dump(rf_model, 'random_forest_model.pkl')
# Out:
# ['random_forest_model.pkl']

# %%
# Load it back in again

rf_model = joblib.load('random_forest_model.pkl')

# %%
from agents.specialist_agent import SpecialistAgent
from agents.frontier_agent import FrontierAgent
from agents.random_forest_agent import RandomForestAgent

# %%
specialist = SpecialistAgent()
frontier = FrontierAgent(collection)
random_forest = RandomForestAgent()

# %%
def description(item):
    return item.prompt.split("to the nearest dollar?\n\n")[1].split("\n\nPrice is $")[0]

# %%
def rf(item):
    return random_forest.price(description(item))

# %%
Tester.test(rf, test)
# Out:
# 1: Guess: $259.52 Truth: $374.41 Error: $114.89 SLE: 0.13 Item: OEM AC Compressor w/A/C Repair Kit For F...
# 2: Guess: $181.15 Truth: $225.11 Error: $43.96 SLE: 0.05 Item: Motorcraft YB3125 Fan Clutch
# 3: Guess: $231.54 Truth: $61.68 Error: $169.86 SLE: 1.72 Item: Dorman 603-159 Front Washer Fluid Reserv...
# 4: Guess: $345.38 Truth: $599.99 Error: $254.61 SLE: 0.30 Item: HP Premium 17.3-inch HD Plus Touchscreen...
# 5: Guess: $196.11 Truth: $16.99 Error: $179.12 SLE: 5.73 Item: 5-Position Super Switch Pickup Selector ...
# 6: Guess: $111.24 Truth: $31.99 Error: $79.25 SLE: 1.50 Item: Horror Bookmarks, Resin Horror Bookmarks...
# 7: Guess: $260.11 Truth: $101.79 Error: $158.32 SLE: 0.87 Item: SK6241 - Stinger 4 Gauge 6000 Series Pow...
# 8: Guess: $252.54 Truth: $289.00 Error: $36.46 SLE: 0.02 Item: Godox ML60Bi LED Light Kit, Handheld LED...
# 9: Guess: $260.56 Truth: $635.86 Error: $375.30 SLE: 0.79 Item: Randall RG75DG3PLUS G3 Plus 100-Watt Com...
# 10: Guess: $179.29 Truth: $65.99 Error: $113.30 SLE: 0.98 Item: HOLDWILL 6 Pack LED Shop Light, 4FT 24W ...
# 11: Guess: $273.75 Truth: $254.21 Error: $19.54 SLE: 0.01 Item: Viking Horns V103C/1005ATK 3 Gallon Air ...
# 12: Guess: $263.56 Truth: $412.99 Error: $149.43 SLE: 0.20 Item: CURT 70110 Custom Tow Bar Base Plate Bra...
# 13: Guess: $155.07 Truth: $205.50 Error: $50.43 SLE: 0.08 Item: 10-Pack Solar HAMMERED BRONZE Finish Pos...
# 14: Guess: $229.11 Truth: $248.23 Error: $19.12 SLE: 0.01 Item: COSTWAY Electric Tumble Dryer, Sliver
# 15: Guess: $257.57 Truth: $399.00 Error: $141.43 SLE: 0.19 Item: FREE SIGNAL TV Transit 32" 12 Volt DC Po...
# 16: Guess: $300.74 Truth: $373.94 Error: $73.20 SLE: 0.05 Item: Bilstein 5100 Monotube Gas Shock Set com...
# 17: Guess: $243.12 Truth: $92.89 Error: $150.23 SLE: 0.91 Item: Sangean K-200 Multi-Function Upright AM/...
# 18: Guess: $127.32 Truth: $51.99 Error: $75.33 SLE: 0.78 Item: Charles Leonard Magnetic Lapboard Class ...
# 19: Guess: $366.13 Truth: $179.00 Error: $187.13 SLE: 0.51 Item: Gigabyte AMD Radeon HD 7870 2 GB GDDR5 D...
# 20: Guess: $106.41 Truth: $19.42 Error: $86.99 SLE: 2.76 Item: 3dRose LLC 8 x 8 x 0.25 Inches Bull Terr...
# 21: Guess: $291.51 Truth: $539.95 Error: $248.44 SLE: 0.38 Item: ROKINON 85mm F1.4 Auto Focus Full Frame ...
# 22: Guess: $200.04 Truth: $147.67 Error: $52.37 SLE: 0.09 Item: AUTOSAVER88 Headlight Assembly Compatibl...
# 23: Guess: $177.39 Truth: $24.99 Error: $152.40 SLE: 3.71 Item: ASI NAUTICAL 2.5 Inches Opera Glasses Bi...
# 24: Guess: $275.75 Truth: $149.00 Error: $126.75 SLE: 0.38 Item: Behringer TUBE OVERDRIVE TO100 Authentic...
# 25: Guess: $87.71 Truth: $16.99 Error: $70.72 SLE: 2.55 Item: Fun Express Insect Finger Puppets - 24 f...
# 26: Guess: $105.27 Truth: $7.99 Error: $97.28 SLE: 6.10 Item: WAFJAMF Roller Stamp Identity Theft Stam...
# 27: Guess: $163.69 Truth: $199.99 Error: $36.30 SLE: 0.04 Item: Capulina Tiffany Floor Lamp 2-Light 16" ...
# 28: Guess: $233.24 Truth: $251.45 Error: $18.21 SLE: 0.01 Item: Apple Watch Series 6 (GPS, 44mm) - Space...
# 29: Guess: $225.64 Truth: $231.62 Error: $5.98 SLE: 0.00 Item: ICON 01725 Tandem Axle Fender Skirt FS17...
# 30: Guess: $215.44 Truth: $135.00 Error: $80.44 SLE: 0.22 Item: SanDisk 128GB Ultra (10 Pack) MicroSD Cl...
# 31: Guess: $222.59 Truth: $356.62 Error: $134.03 SLE: 0.22 Item: Velvac 2020,L,C/Hr,W,E2003,102",Bk - 715...
# 32: Guess: $245.19 Truth: $257.99 Error: $12.80 SLE: 0.00 Item: TCMT Passenger Backrest Sissy Bar & Lugg...
# 33: Guess: $209.08 Truth: $27.99 Error: $181.09 SLE: 3.92 Item: Alnicov 63.5MM Brass Tremolo Block，Tremo...
# 34: Guess: $258.69 Truth: $171.20 Error: $87.49 SLE: 0.17 Item: Subaru Forester Outback Legacy OEM Engin...
# 35: Guess: $211.51 Truth: $225.00 Error: $13.49 SLE: 0.00 Item: Richmond Auto Upholstery - 2012 Dodge Ra...
# 36: Guess: $208.61 Truth: $105.00 Error: $103.61 SLE: 0.46 Item: AP-39 Automotive Paint Primer Grey 2K Ur...
# 37: Guess: $243.56 Truth: $299.99 Error: $56.43 SLE: 0.04 Item: Road Top Wireless Carplay Retrofit Kit D...
# 38: Guess: $584.58 Truth: $535.09 Error: $49.49 SLE: 0.01 Item: Gibson Performance Exhaust 5658 Aluminiz...
# 39: Guess: $171.48 Truth: $12.33 Error: $159.15 SLE: 6.55 Item: Bella Tunno Happy Links - Baby Montessor...
# 40: Guess: $220.00 Truth: $84.99 Error: $135.01 SLE: 0.89 Item: CANMORE H300 Handheld GPS Golf Device, S...
# 41: Guess: $127.54 Truth: $15.99 Error: $111.55 SLE: 4.10 Item: DCPOWER AC Adapter Compatible Replacemen...
# 42: Guess: $178.18 Truth: $62.44 Error: $115.74 SLE: 1.08 Item: Sharp, VX2128V, Commercial Desktop Calcu...
# 43: Guess: $131.21 Truth: $82.99 Error: $48.22 SLE: 0.21 Item: Melissa & Doug Lifelike Plush Stork Gian...
# 44: Guess: $277.91 Truth: $599.95 Error: $322.04 SLE: 0.59 Item: Sony SSCS8 2-Way 3-Driver Center Channel...
# 45: Guess: $294.48 Truth: $194.99 Error: $99.49 SLE: 0.17 Item: ASUS Chromebook CX1, 14" Full HD NanoEdg...
# 46: Guess: $254.77 Truth: $344.95 Error: $90.18 SLE: 0.09 Item: FiiO X7 32GB Hi-Res Lossless Music Playe...
# 47: Guess: $69.12 Truth: $37.99 Error: $31.13 SLE: 0.34 Item: TORRO Leather Case Compatible with iPhon...
# 48: Guess: $223.92 Truth: $224.35 Error: $0.43 SLE: 0.00 Item: Universal Air Conditioner KT 1031 A/C Co...
# 49: Guess: $508.43 Truth: $814.00 Error: $305.57 SLE: 0.22 Item: Street Series Stainless Performance Cat-...
# 50: Guess: $483.03 Truth: $439.88 Error: $43.15 SLE: 0.01 Item: Lenovo IdeaPad 3 14-inch Laptop, 14.0-in...
# 51: Guess: $249.06 Truth: $341.43 Error: $92.37 SLE: 0.10 Item: Access Bed Covers TonnoSport 22050219 - ...
# 52: Guess: $189.76 Truth: $46.78 Error: $142.98 SLE: 1.92 Item: G.I. JOE Hasbro 3 3/4" Wave 5 Action Fig...
# 53: Guess: $176.59 Truth: $171.44 Error: $5.15 SLE: 0.00 Item: T&S Brass B-0232-BST Double Pantry Fauce...
# 54: Guess: $221.21 Truth: $458.00 Error: $236.79 SLE: 0.53 Item: ZTUOAUMA Fuel Injection Pump 3090942 309...
# 55: Guess: $275.76 Truth: $130.75 Error: $145.01 SLE: 0.55 Item: 2AP18AA#ABA Hp Prime Graphing Calculator...
# 56: Guess: $195.30 Truth: $83.81 Error: $111.49 SLE: 0.70 Item: Lowrance 000-0119-83 Nmea 2000 25' Exten...
# 57: Guess: $195.59 Truth: $386.39 Error: $190.80 SLE: 0.46 Item: Jeep Genuine Accessories 82213051 Hood L...
# 58: Guess: $180.21 Truth: $169.00 Error: $11.21 SLE: 0.00 Item: GODOX CB-06 Hard Carrying Case with Whee...
# 59: Guess: $177.42 Truth: $17.95 Error: $159.47 SLE: 5.03 Item: Au-Tomotive Gold, INC. Ford Black Valet ...
# 60: Guess: $219.14 Truth: $269.00 Error: $49.86 SLE: 0.04 Item: Snailfly Black Roof Rack Rail + Cross Ba...
# 61: Guess: $200.79 Truth: $77.77 Error: $123.02 SLE: 0.88 Item: KING SHA Anti Glare LED Track Lighting H...
# 62: Guess: $233.65 Truth: $88.99 Error: $144.66 SLE: 0.92 Item: APS Compatible with Chevy Silverado 1500...
# 63: Guess: $245.54 Truth: $364.41 Error: $118.87 SLE: 0.15 Item: Wilwood Engineering 14011291R Brake Cali...
# 64: Guess: $166.73 Truth: $127.03 Error: $39.70 SLE: 0.07 Item: ACDelco Gold 336-1925A Starter, Remanufa...
# 65: Guess: $585.65 Truth: $778.95 Error: $193.30 SLE: 0.08 Item: UWS EC10783 69-Inch Matte Black Heavy-Wa...
# 66: Guess: $440.93 Truth: $206.66 Error: $234.27 SLE: 0.57 Item: Dell Latitude E5440 14in Business Laptop...
# 67: Guess: $181.14 Truth: $35.94 Error: $145.20 SLE: 2.55 Item: (Plug and Play) Spare Tire Brake Light W...
# 68: Guess: $231.22 Truth: $149.00 Error: $82.22 SLE: 0.19 Item: The Ultimate Roadside Rescue Assistant
# 69: Guess: $226.84 Truth: $251.98 Error: $25.14 SLE: 0.01 Item: Brand New 18" x 8.5" Replacement Wheel f...
# 70: Guess: $204.47 Truth: $160.00 Error: $44.47 SLE: 0.06 Item: Headlight Headlamp LH Left & RH Right Pa...
# 71: Guess: $144.31 Truth: $39.99 Error: $104.32 SLE: 1.60 Item: Lilo And Stitch Deluxe Oversize Print La...
# 72: Guess: $222.21 Truth: $362.41 Error: $140.20 SLE: 0.24 Item: AC Compressor & A/C Clutch For Hyundai A...
# 73: Guess: $216.81 Truth: $344.00 Error: $127.19 SLE: 0.21 Item: House Of Troy PIN475-AB Pinnacle Collect...
# 74: Guess: $236.41 Truth: $25.09 Error: $211.32 SLE: 4.88 Item: Juno T29 WH Floating Electrical Feed Sin...
# 75: Guess: $201.08 Truth: $175.95 Error: $25.13 SLE: 0.02 Item: Sherman GO-PARTS - for 2013-2016 Toyota ...
# 76: Guess: $240.67 Truth: $132.64 Error: $108.03 SLE: 0.35 Item: Roland RPU-3 Electronic Keyboard Pedal o...
# 77: Guess: $261.05 Truth: $422.99 Error: $161.94 SLE: 0.23 Item: Rockland VMI14 12,000 Pound 12 Volt DC E...
# 78: Guess: $198.57 Truth: $146.48 Error: $52.09 SLE: 0.09 Item: Max Advanced Brakes Elite XDS Front Cros...
# 79: Guess: $201.41 Truth: $156.83 Error: $44.58 SLE: 0.06 Item: Quality-Built 11030 Premium Quality Alte...
# 80: Guess: $268.97 Truth: $251.99 Error: $16.98 SLE: 0.00 Item: Lucida LG-510 Student Classical Guitar, ...
# 81: Guess: $231.32 Truth: $940.33 Error: $709.01 SLE: 1.96 Item: Longacre 52-79800 Aluminum Turn Plates
# 82: Guess: $196.66 Truth: $52.99 Error: $143.67 SLE: 1.68 Item: Motion Pro 08-0380 Adjustable Torque Wre...
# 83: Guess: $150.12 Truth: $219.95 Error: $69.83 SLE: 0.14 Item: Glyph Thunderbolt 3 NVMe Dock (0 GB)
# 84: Guess: $232.49 Truth: $441.03 Error: $208.54 SLE: 0.41 Item: TOYO Open Country MT Performance Radial ...
# 85: Guess: $262.02 Truth: $168.98 Error: $93.04 SLE: 0.19 Item: Razer Seiren X USB Streaming Microphone ...
# 86: Guess: $112.00 Truth: $2.49 Error: $109.51 SLE: 12.09 Item: Happy Birthday to Dad From Your Daughter...
# 87: Guess: $167.61 Truth: $98.62 Error: $68.99 SLE: 0.28 Item: Little Tikes My Real Jam First Concert S...
# 88: Guess: $221.60 Truth: $256.95 Error: $35.35 SLE: 0.02 Item: Studio M Peace and Harmony Art Pole Comm...
# 89: Guess: $211.90 Truth: $30.99 Error: $180.91 SLE: 3.59 Item: MyVolts 12V Power Supply Adaptor Compati...
# 90: Guess: $373.84 Truth: $569.84 Error: $196.00 SLE: 0.18 Item: Dell Latitude 7212 Rugged Extreme Tablet...
# 91: Guess: $204.53 Truth: $177.99 Error: $26.54 SLE: 0.02 Item: Covermates Contour Fit Car Cover - Light...
# 92: Guess: $580.46 Truth: $997.99 Error: $417.53 SLE: 0.29 Item: Westin 57-4025 Black HDX Grille Guard fi...
# 93: Guess: $266.28 Truth: $219.00 Error: $47.28 SLE: 0.04 Item: Fieldpiece JL2 Job Link Wireless App Tra...
# 94: Guess: $279.14 Truth: $225.55 Error: $53.59 SLE: 0.05 Item: hansgrohe Talis S Modern Premium Easy Cl...
# 95: Guess: $306.05 Truth: $495.95 Error: $189.90 SLE: 0.23 Item: G-Technology G-SPEED eS PRO High-Perform...
# 96: Guess: $628.68 Truth: $942.37 Error: $313.69 SLE: 0.16 Item: DreamLine SHDR-1960723L-01 Shower Door, ...
# 97: Guess: $179.79 Truth: $1.94 Error: $177.85 SLE: 16.97 Item: Sanctuary Square Backplate Finish: Oiled...
# 98: Guess: $196.23 Truth: $284.34 Error: $88.11 SLE: 0.14 Item: Pelican Protector 1750 Long Case - Multi...
# 99: Guess: $189.81 Truth: $171.90 Error: $17.91 SLE: 0.01 Item: Brock Replacement Driver and Passenger H...
# 100: Guess: $240.74 Truth: $144.99 Error: $95.75 SLE: 0.25 Item: Carlinkit Ai Box Mini, Android 11, Multi...
# 101: Guess: $227.71 Truth: $470.47 Error: $242.76 SLE: 0.52 Item: StarDot NetCamLIVE2 YouTube Live Stream ...
# 102: Guess: $231.48 Truth: $66.95 Error: $164.53 SLE: 1.51 Item: Atomic Compatible FILXXCAR0016 16x25x5 M...
# 103: Guess: $154.51 Truth: $117.00 Error: $37.51 SLE: 0.08 Item: Bandai Awakening of S. H. s.h.figuarts s...
# 104: Guess: $237.22 Truth: $172.14 Error: $65.08 SLE: 0.10 Item: Fit System 62135G Passenger Side Towing ...
# 105: Guess: $278.77 Truth: $392.74 Error: $113.97 SLE: 0.12 Item: Black Horse Black Aluminum Exceed Runnin...
# 106: Guess: $85.53 Truth: $16.99 Error: $68.54 SLE: 2.47 Item: Dearsun Twinkle Star Color Night Light P...
# 107: Guess: $92.28 Truth: $1.34 Error: $90.94 SLE: 13.58 Item: Pokemon - Gallade Spirit Link (83/108) -...
# 108: Guess: $272.55 Truth: $349.98 Error: $77.43 SLE: 0.06 Item: Ibanez GA34STCE-NT GIO Series Classical ...
# 109: Guess: $242.22 Truth: $370.71 Error: $128.49 SLE: 0.18 Item: Set 2 Heavy Duty 12-16.5 12x16.5 12 Ply ...
# 110: Guess: $165.26 Truth: $65.88 Error: $99.38 SLE: 0.83 Item: Hairpin Table Legs 28" Heavy Duty Hairpi...
# 111: Guess: $226.36 Truth: $229.99 Error: $3.63 SLE: 0.00 Item: Marada Racing Seat with Adjustable Slide...
# 112: Guess: $175.70 Truth: $9.14 Error: $166.56 SLE: 8.17 Item: Remington Industries 24UL1007STRWHI25 24...
# 113: Guess: $459.82 Truth: $199.00 Error: $260.82 SLE: 0.70 Item: Acer S3-391-6046 13.3-inch Ultrabook, In...
# 114: Guess: $228.49 Truth: $109.99 Error: $118.50 SLE: 0.53 Item: ICBEAMER 7" RGB LED Headlights Bulb Halo...
# 115: Guess: $333.82 Truth: $570.42 Error: $236.60 SLE: 0.29 Item: R1 Concepts Front Rear Brakes and Rotors...
# 116: Guess: $242.36 Truth: $279.99 Error: $37.63 SLE: 0.02 Item: Camplux 2.64 GPM Tankless , Outdoor Port...
# 117: Guess: $127.14 Truth: $30.99 Error: $96.15 SLE: 1.93 Item: KNOKLOCK 10 Pack 3.75 Inch(96mm) Kitchen...
# 118: Guess: $235.67 Truth: $31.99 Error: $203.68 SLE: 3.88 Item: Valley Enterprises Yaesu USB FTDI CT-62 ...
# 119: Guess: $185.46 Truth: $15.90 Error: $169.56 SLE: 5.76 Item: G9 LED Light Bulbs，8W，75W 100W replaceme...
# 120: Guess: $161.79 Truth: $45.99 Error: $115.80 SLE: 1.54 Item: ZCHAOZ 4 Lights Antique White Farmhouse ...
# 121: Guess: $190.78 Truth: $113.52 Error: $77.26 SLE: 0.27 Item: Honeywell TH8320R1003 Honeywell VisionPr...
# 122: Guess: $260.09 Truth: $516.99 Error: $256.90 SLE: 0.47 Item: Patriot Exhaust H8013-1 1-7/8" Clippster...
# 123: Guess: $216.75 Truth: $196.99 Error: $19.76 SLE: 0.01 Item: Fitrite Autopart New Front Left Driver S...
# 124: Guess: $160.75 Truth: $46.55 Error: $114.20 SLE: 1.50 Item: Technical Precision Replacement for GE G...
# 125: Guess: $264.16 Truth: $356.99 Error: $92.83 SLE: 0.09 Item: Covercraft Carhartt SeatSaver Front Row ...
# 126: Guess: $187.48 Truth: $319.95 Error: $132.47 SLE: 0.28 Item: Sennheiser SD Pro 2 (506008) - Double-Si...
# 127: Guess: $194.47 Truth: $96.06 Error: $98.41 SLE: 0.49 Item: Hitachi MAF0110 Mass Air Flow Sensor
# 128: Guess: $264.82 Truth: $190.99 Error: $73.83 SLE: 0.11 Item: AmScope SE305R-P-LED-PS36A 10X-30X LED C...
# 129: Guess: $203.77 Truth: $257.95 Error: $54.18 SLE: 0.06 Item: Front Left Driver Side Window Regulator ...
# 130: Guess: $194.58 Truth: $62.95 Error: $131.63 SLE: 1.25 Item: Premium Replica Hubcap Set, Fits Nissan ...
# 131: Guess: $123.89 Truth: $47.66 Error: $76.23 SLE: 0.89 Item: Excellerations Phonics Spelling Game for...
# 132: Guess: $284.00 Truth: $226.99 Error: $57.01 SLE: 0.05 Item: RC4WD BigDog Dual Axle Scale Car/Truck T...
# 133: Guess: $277.28 Truth: $359.95 Error: $82.67 SLE: 0.07 Item: Unknown Stage 2 Clutch Kit - Low Altitud...
# 134: Guess: $241.14 Truth: $78.40 Error: $162.74 SLE: 1.24 Item: 2002-2008 Dodge Ram 1500 Mopar 4X4 Emble...
# 135: Guess: $208.90 Truth: $172.77 Error: $36.13 SLE: 0.04 Item: Pro Comp Alloys Series 89 Wheel with Pol...
# 136: Guess: $226.35 Truth: $316.45 Error: $90.10 SLE: 0.11 Item: Detroit Axle - Front Rear Strut & Coil S...
# 137: Guess: $224.42 Truth: $87.99 Error: $136.43 SLE: 0.86 Item: ECCPP Rear Wheel Axle Replacement fit fo...
# 138: Guess: $253.28 Truth: $226.63 Error: $26.65 SLE: 0.01 Item: Dell Latitude E6520 Intel i7-2720QM 2.20...
# 139: Guess: $196.39 Truth: $31.49 Error: $164.90 SLE: 3.26 Item: F FIERCE CYCLE 251pcs Black Universal Mo...
# 140: Guess: $186.10 Truth: $196.00 Error: $9.90 SLE: 0.00 Item: Flash Furniture 4 Pk. HERCULES Series 88...
# 141: Guess: $235.50 Truth: $78.40 Error: $157.10 SLE: 1.19 Item: B&M 30287 Throttle Valve/Kickdown Cable,...
# 142: Guess: $196.62 Truth: $116.25 Error: $80.37 SLE: 0.27 Item: Gates TCK226 PowerGrip Premium Timing Be...
# 143: Guess: $168.80 Truth: $112.78 Error: $56.02 SLE: 0.16 Item: Monroe Shocks & Struts Quick-Strut 17149...
# 144: Guess: $185.16 Truth: $27.32 Error: $157.84 SLE: 3.55 Item: Feit Electric BPMR16/GU10/930CA/6 35W EQ...
# 145: Guess: $150.64 Truth: $145.91 Error: $4.73 SLE: 0.00 Item: Yellow Jacket 2806 Contractor Extension ...
# 146: Guess: $230.30 Truth: $171.09 Error: $59.21 SLE: 0.09 Item: Garage-Pro Tailgate SET Compatible with ...
# 147: Guess: $169.06 Truth: $167.95 Error: $1.11 SLE: 0.00 Item: 3M Perfect It Buffing and Polishing Kit ...
# 148: Guess: $113.67 Truth: $28.49 Error: $85.18 SLE: 1.84 Item: Chinese Style Dollhouse Model DIY Miniat...
# 149: Guess: $189.06 Truth: $122.23 Error: $66.83 SLE: 0.19 Item: Generic NRG Innovations SRK-161H Steerin...
# 150: Guess: $132.56 Truth: $32.99 Error: $99.57 SLE: 1.87 Item: Learning Resources Coding Critters Range...
# 151: Guess: $212.35 Truth: $71.20 Error: $141.15 SLE: 1.17 Item: Bosch Automotive 15463 Oxygen Sensor, OE...
# 152: Guess: $113.74 Truth: $112.75 Error: $0.99 SLE: 0.00 Item: Case of 24-2 Inch Blue Painters Tape - 6...
# 153: Guess: $194.76 Truth: $142.43 Error: $52.33 SLE: 0.10 Item: MOCA Engine Water Pump & Fan Clutch fit ...
# 154: Guess: $222.42 Truth: $398.99 Error: $176.57 SLE: 0.34 Item: SAREMAS Foot Step Bars for Hyundai Palis...
# 155: Guess: $330.45 Truth: $449.00 Error: $118.55 SLE: 0.09 Item: Gretsch G9210 Square Neck Boxcar Mahogan...
# 156: Guess: $251.06 Truth: $189.00 Error: $62.06 SLE: 0.08 Item: NikoMaku Mirror Dash Cam Front and Rear ...
# 157: Guess: $219.09 Truth: $120.91 Error: $98.18 SLE: 0.35 Item: Fenix HP25R v2.0 USB-C Rechargeable Head...
# 158: Guess: $298.37 Truth: $203.53 Error: $94.84 SLE: 0.15 Item: R&L Racing Heavy Duty Roll-Up Soft Tonne...
# 159: Guess: $270.38 Truth: $349.99 Error: $79.61 SLE: 0.07 Item: Garmin 010-02258-10 GPSMAP 64sx, Handhel...
# 160: Guess: $103.73 Truth: $34.35 Error: $69.38 SLE: 1.18 Item: Brown 5-7/8" X 8-1/2" X 3/16" Thick Heav...
# 161: Guess: $183.59 Truth: $384.99 Error: $201.40 SLE: 0.54 Item: GAOMON PD2200 Pen Display & 20 Pen Nibs ...
# 162: Guess: $260.07 Truth: $211.00 Error: $49.07 SLE: 0.04 Item: VXMOTOR for 97-03 Ford F150/F250 Lightdu...
# 163: Guess: $324.38 Truth: $129.00 Error: $195.38 SLE: 0.84 Item: HP EliteBook 2540p Intel Core i7-640LM X...
# 164: Guess: $171.20 Truth: $111.45 Error: $59.75 SLE: 0.18 Item: Green EPX Mixing Nozzles 100-Pack-fits 3...
# 165: Guess: $151.20 Truth: $81.12 Error: $70.08 SLE: 0.38 Item: Box Partners 6 1/4 x 3 1/8" 13 Pt. Manil...
# 166: Guess: $295.61 Truth: $457.08 Error: $161.47 SLE: 0.19 Item: Vixen Air 1/2" NPT Air Ride Suspension H...
# 167: Guess: $165.90 Truth: $49.49 Error: $116.41 SLE: 1.43 Item: Smart Floor Lamp, 2700-6500K+RGBPink Mul...
# 168: Guess: $211.10 Truth: $80.56 Error: $130.54 SLE: 0.91 Item: SOZG 324mm Wheelbase Body Shell RC Car B...
# 169: Guess: $259.31 Truth: $278.39 Error: $19.08 SLE: 0.01 Item: Mickey Thompson ET Street S/S Racing Rad...
# 170: Guess: $219.24 Truth: $364.50 Error: $145.26 SLE: 0.26 Item: Pirelli 275/40R20 106W XL RFT P0 PZ4-LUX...
# 171: Guess: $264.32 Truth: $378.99 Error: $114.67 SLE: 0.13 Item: Torklift C3212 Rear Tie Down
# 172: Guess: $208.58 Truth: $165.28 Error: $43.30 SLE: 0.05 Item: Cardone 78-4226 Remanufactured Ford Comp...
# 173: Guess: $198.99 Truth: $56.74 Error: $142.25 SLE: 1.54 Item: Kidde AccessPoint 001798 Supra TouchPoin...
# 174: Guess: $213.70 Truth: $307.95 Error: $94.25 SLE: 0.13 Item: 3M Protecta 3100414 Self Retracting Life...
# 175: Guess: $207.16 Truth: $38.00 Error: $169.16 SLE: 2.80 Item: Plantronics 89435-01 Wired Headset, Blac...
# 176: Guess: $159.80 Truth: $53.00 Error: $106.80 SLE: 1.19 Item: Logitech K750 Wireless Solar Keyboard fo...
# 177: Guess: $300.96 Truth: $498.00 Error: $197.04 SLE: 0.25 Item: Olympus PEN E-PL9 Body Only with 3-Inch ...
# 178: Guess: $194.16 Truth: $53.99 Error: $140.17 SLE: 1.60 Item: Beck/Arnley 051-6066 Hub & Bearing Assem...
# 179: Guess: $221.58 Truth: $350.00 Error: $128.42 SLE: 0.21 Item: Eibach Pro-Kit Performance Springs E10-6...
# 180: Guess: $171.93 Truth: $299.95 Error: $128.02 SLE: 0.31 Item: LEGO DC Batman 1989 Batwing 76161 Displa...
# 181: Guess: $190.86 Truth: $94.93 Error: $95.93 SLE: 0.48 Item: Kingston Brass KS3608PL Restoration 4-In...
# 182: Guess: $284.07 Truth: $379.00 Error: $94.93 SLE: 0.08 Item: Polk Vanishing Series 265-LS In-Wall 3-W...
# 183: Guess: $228.56 Truth: $299.95 Error: $71.39 SLE: 0.07 Item: Spec-D Tuning LED Projector Headlights G...
# 184: Guess: $77.76 Truth: $24.99 Error: $52.77 SLE: 1.23 Item: RICHMOND & FINCH Airpod Pro Case, Green ...
# 185: Guess: $221.41 Truth: $41.04 Error: $180.37 SLE: 2.78 Item: LFA Industries 43B-5A-33JT 1/16-1/2-1.5-...
# 186: Guess: $183.58 Truth: $327.90 Error: $144.32 SLE: 0.33 Item: SAUTVS LED Headlight Assembly for Slings...
# 187: Guess: $144.41 Truth: $10.99 Error: $133.42 SLE: 6.23 Item: 2 Pack Combo Womens Safety Glasses Impac...
# 188: Guess: $192.56 Truth: $14.99 Error: $177.57 SLE: 6.22 Item: Arepa - Venezuelan cuisine - Venezuela P...
# 189: Guess: $159.80 Truth: $84.95 Error: $74.85 SLE: 0.39 Item: Schlage Lock Company KS23D2300 Padlock, ...
# 190: Guess: $203.60 Truth: $111.00 Error: $92.60 SLE: 0.36 Item: Techni Mobili White Sit to Stand Mobile ...
# 191: Guess: $152.29 Truth: $123.73 Error: $28.56 SLE: 0.04 Item: Special Lite Products Contemporary Wall ...
# 192: Guess: $217.70 Truth: $557.38 Error: $339.68 SLE: 0.88 Item: Tascam DP-24SD 24-Track Digital Portastu...
# 193: Guess: $204.96 Truth: $95.55 Error: $109.41 SLE: 0.57 Item: Glow Lighting 636CC10SP Vista Crystal Fl...
# 194: Guess: $233.87 Truth: $154.00 Error: $79.87 SLE: 0.17 Item: Z3 Wind Deflector, Smoke Tint, Lexan, Wi...
# 195: Guess: $316.90 Truth: $198.99 Error: $117.91 SLE: 0.21 Item: Olympus E-20 5MP Digital Camera w/ 4x Op...
# 196: Guess: $212.39 Truth: $430.44 Error: $218.05 SLE: 0.50 Item: PHYNEDI 1:1000 World Trade Center (1973-...
# 197: Guess: $105.88 Truth: $45.67 Error: $60.21 SLE: 0.69 Item: YANGHUAN Unstable Unicorns Adventure Car...
# 198: Guess: $231.65 Truth: $249.00 Error: $17.35 SLE: 0.01 Item: Interlogix NX-1820E NetworX Touch Screen...
# 199: Guess: $203.90 Truth: $42.99 Error: $160.91 SLE: 2.37 Item: Steering Damper,Universal Motorcycle Han...
# 200: Guess: $217.88 Truth: $181.33 Error: $36.55 SLE: 0.03 Item: Amprobe TIC 410A Hot Stick Attachment
# 201: Guess: $161.92 Truth: $6.03 Error: $155.89 SLE: 9.88 Item: MyCableMart 3.5mm Plug/Jack, 4 Conductor...
# 202: Guess: $78.86 Truth: $29.99 Error: $48.87 SLE: 0.90 Item: OtterBox + Pop Symmetry Series Case for ...
# 203: Guess: $470.05 Truth: $899.00 Error: $428.95 SLE: 0.42 Item: Dell XPS X8700-1572BLK Desktop ( Intel C...
# 204: Guess: $236.17 Truth: $399.99 Error: $163.82 SLE: 0.28 Item: Franklin Iron Works Sperry Industrial Br...
# 205: Guess: $141.66 Truth: $4.66 Error: $137.00 SLE: 10.41 Item: Avery Legal Dividers, Standard Collated ...
# 206: Guess: $216.90 Truth: $261.41 Error: $44.51 SLE: 0.03 Item: Moen 8346 Commercial Posi-Temp Pressure ...
# 207: Guess: $225.74 Truth: $136.97 Error: $88.77 SLE: 0.25 Item: Carlisle Versa Trail ATR All Terrain Rad...
# 208: Guess: $203.15 Truth: $79.00 Error: $124.15 SLE: 0.88 Item: SUNWAYFOTO 44mm Tripod Ball Head Arca Co...
# 209: Guess: $236.82 Truth: $444.99 Error: $208.17 SLE: 0.40 Item: NanoBeam AC NBE-5AC-Gen2-US 4 Units 5GHz...
# 210: Guess: $263.40 Truth: $411.94 Error: $148.54 SLE: 0.20 Item: WULF 4" Front 2" Rear Leveling Lift Kit ...
# 211: Guess: $183.02 Truth: $148.40 Error: $34.62 SLE: 0.04 Item: Alera ALEVABFMC Valencia Series Mobile B...
# 212: Guess: $112.26 Truth: $244.99 Error: $132.73 SLE: 0.60 Item: YU-GI-OH! Ignition Assault Booster Box
# 213: Guess: $170.18 Truth: $86.50 Error: $83.68 SLE: 0.45 Item: 48" x 36" Extra-Large Framed Magnetic Bl...
# 214: Guess: $285.21 Truth: $297.95 Error: $12.74 SLE: 0.00 Item: Dell Latitude D620 Renewed Notebook PC
# 215: Guess: $569.68 Truth: $399.99 Error: $169.69 SLE: 0.12 Item: acer Aspire 5 Laptop, AMD Ryzen 3 5300U ...
# 216: Guess: $206.40 Truth: $599.00 Error: $392.60 SLE: 1.13 Item: Elk 31080/6RC-GRN 30 by 6-Inch Viva 6-Li...
# 217: Guess: $210.66 Truth: $105.99 Error: $104.67 SLE: 0.47 Item: Barbie Top Model Doll
# 218: Guess: $293.24 Truth: $689.00 Error: $395.76 SLE: 0.73 Item: Danby Designer 20-In. Electric Range wit...
# 219: Guess: $259.71 Truth: $404.99 Error: $145.28 SLE: 0.20 Item: FixtureDisplays® Metal Truss Podium Doub...
# 220: Guess: $227.55 Truth: $207.76 Error: $19.79 SLE: 0.01 Item: ACDelco 13597235 GM Original Equipment A...
# 221: Guess: $210.13 Truth: $171.82 Error: $38.31 SLE: 0.04 Item: EBC S1KF1135 Stage-1 Premium Street Brak...
# 222: Guess: $266.37 Truth: $293.24 Error: $26.87 SLE: 0.01 Item: FXR Men's Boost FX Jacket (Black/Orange/...
# 223: Guess: $244.22 Truth: $374.95 Error: $130.73 SLE: 0.18 Item: SuperATV Scratch Resistant 3-in-1 Flip W...
# 224: Guess: $214.87 Truth: $111.99 Error: $102.88 SLE: 0.42 Item: SBU 3 Layer All Weather Mini Van Car Cov...
# 225: Guess: $100.29 Truth: $42.99 Error: $57.30 SLE: 0.70 Item: 2 Pack Outdoor Brochure Holder Advertisi...
# 226: Guess: $148.67 Truth: $116.71 Error: $31.96 SLE: 0.06 Item: Monroe Shocks & Struts Quick-Strut 17158...
# 227: Guess: $227.65 Truth: $118.61 Error: $109.04 SLE: 0.42 Item: Elements of Design Magellan EB235AL Thre...
# 228: Guess: $209.39 Truth: $147.12 Error: $62.27 SLE: 0.12 Item: GM Genuine Parts 15-62961 Air Conditioni...
# 229: Guess: $181.23 Truth: $119.99 Error: $61.24 SLE: 0.17 Item: Baseus 17-in-1 USB C Docking Station to ...
# 230: Guess: $178.54 Truth: $369.98 Error: $191.44 SLE: 0.53 Item: Whitehall™ Personalized Whitehall Capito...
# 231: Guess: $287.07 Truth: $315.55 Error: $28.48 SLE: 0.01 Item: Pro Circuit Works Pipe PY05250 for 02-19...
# 232: Guess: $269.35 Truth: $190.99 Error: $78.36 SLE: 0.12 Item: HYANKA 15 "1200W Professional DJ Speaker...
# 233: Guess: $195.16 Truth: $155.00 Error: $40.16 SLE: 0.05 Item: Bluetooth X6BT Card Reader Writer Encode...
# 234: Guess: $313.08 Truth: $349.99 Error: $36.91 SLE: 0.01 Item: AIRAID Cold Air Intake System by K&N: In...
# 235: Guess: $246.84 Truth: $249.99 Error: $3.15 SLE: 0.00 Item: Bostingner Shower Faucets Sets Complete,...
# 236: Guess: $198.27 Truth: $42.99 Error: $155.28 SLE: 2.28 Item: PIT66 Front Bumper Turn Signal Lights, C...
# 237: Guess: $58.17 Truth: $17.99 Error: $40.18 SLE: 1.29 Item: Caseology Bumpy Compatible with Google P...
# 238: Guess: $235.94 Truth: $425.00 Error: $189.06 SLE: 0.34 Item: Fleck 2510 Timer Mechanical Filter Contr...
# 239: Guess: $300.98 Truth: $249.99 Error: $50.99 SLE: 0.03 Item: Haloview MC7108 Wireless RV Backup Camer...
# 240: Guess: $203.02 Truth: $138.23 Error: $64.79 SLE: 0.15 Item: Schmidt Spiele - Manhattan
# 241: Guess: $258.62 Truth: $414.99 Error: $156.37 SLE: 0.22 Item: Corsa 14333 Tip Kit (Ford Mustang GT)
# 242: Guess: $210.56 Truth: $168.28 Error: $42.28 SLE: 0.05 Item: Hoshizaki FM116A Fan Motor Kit 1
# 243: Guess: $185.33 Truth: $199.99 Error: $14.66 SLE: 0.01 Item: BAINUO Antler Chandelier Lighting,6 Ligh...
# 244: Guess: $216.38 Truth: $126.70 Error: $89.68 SLE: 0.28 Item: DNA MOTORING HL-OH-FEXP06-SM-AM Smoke Le...
# 245: Guess: $210.06 Truth: $5.91 Error: $204.15 SLE: 11.69 Item: Wera Stainless 3840/1 TS 2.5mm Hex Inser...
# 246: Guess: $264.30 Truth: $193.06 Error: $71.24 SLE: 0.10 Item: Celestron - PowerSeeker 127EQ Telescope ...
# 247: Guess: $232.05 Truth: $249.99 Error: $17.94 SLE: 0.01 Item: NHOPEEW 10.1inch Android Car Radio Carpl...
# 248: Guess: $234.26 Truth: $64.12 Error: $170.14 SLE: 1.65 Item: Other Harmonica (Suzuki-2Timer24- A)
# 249: Guess: $241.93 Truth: $114.99 Error: $126.94 SLE: 0.55 Item: Harley Air Filter Venturi Intake Air Cle...
# 250: Guess: $271.74 Truth: $926.00 Error: $654.26 SLE: 1.50 Item: Elite Screens Edge Free Ambient Light Re...

# %%
product = "Quadcast HyperX condenser mic for high quality audio for podcasting"

# %%
# !modal setup
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Was not able to launch web browsere web browserer
# Please go to this URL manually and complete the flow:
#
# ]8;id=163063;https://modal.com/token-flow/tf-RyGnX7344RG3xjSeYhBDPC\https://modal.com/token-flow/tf-RyGnX7344RG3xjSeYhBDPC]8;;\
#
# ⠋ Waiting for authentication in the web browser
# ⠹ Waiting for token flow to complete... (attempt 2)
# Web authentication finished successfully!
# Token is connected to the kervin5 workspace.
# Verifying token against https://api.modal.com
# Token verified successfully!
# ⠋ Storing token
# Token written to /home/kervin/.modal.toml in profile kervin5.

# %%
print(specialist.price(product))
print(frontier.price(product))
print(random_forest.price(product))
# Out:
# 189.0
# 195.19
# 229.75172

# %%
specialists = []
frontiers = []
random_forests = []
prices = []
for item in tqdm(test[1000:1250]):
    text = description(item)
    specialists.append(specialist.price(text))
    frontiers.append(frontier.price(text))
    random_forests.append(random_forest.price(text))
    prices.append(item.price)
# Out:
# 100%|██████████| 250/250 [14:42<00:00,  3.53s/it]

# %%
mins = [min(s,f,r) for s,f,r in zip(specialists, frontiers, random_forests)]
maxes = [max(s,f,r) for s,f,r in zip(specialists, frontiers, random_forests)]

X = pd.DataFrame({
    'Specialist': specialists,
    'Frontier': frontiers,
    'RandomForest': random_forests,
    'Min': mins,
    'Max': maxes,
})

# Convert y to a Series
y = pd.Series(prices)

# %%
# Train a Linear Regression
np.random.seed(42)

lr = LinearRegression()
lr.fit(X, y)

feature_columns = X.columns.tolist()

for feature, coef in zip(feature_columns, lr.coef_):
    print(f"{feature}: {coef:.2f}")
print(f"Intercept={lr.intercept_:.2f}")
# Out:
# Specialist: 0.54
# Frontier: 0.24
# RandomForest: -0.32
# Min: 0.27
# Max: 0.21
# Intercept=35.10

# %%
joblib.dump(lr, 'ensemble_model.pkl')
# Out:
# ['ensemble_model.pkl']

# %%
from agents.ensemble_agent import EnsembleAgent
ensemble = EnsembleAgent(collection)

# %%
ensemble.price(product)
# Out:
# 207.85991312910977

# %%
def ensemble_pricer(item):
    return max(0,ensemble.price(description(item)))

# %%
Tester.test(ensemble_pricer, test)

# %% [markdown]
# # WHAT A DAY!
#
# We got so much done - a Fronter RAG pipeline, a Random Forest model using transformer-based encodings, and an Ensemble model.
#
# You can do better, for sure!
#
# Tweak this, and try adding components into the ensemble, to beat my performance.
