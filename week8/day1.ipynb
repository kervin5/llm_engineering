# %% [markdown]
# # Welcome to a very busy Week 8 folder
#
# ## We have lots to do this week!
#
# We'll move at a faster pace than usual, particularly as you're becoming proficient LLM engineers.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Especially important this week: pull the latest</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a <a href="https://chatgpt.com/share/6734e705-3270-8012-a074-421661af6ba9">git pull and merge your changes as needed</a>. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/><br/>
#             After you've pulled the code, from the llm_engineering directory, in an Anaconda prompt (PC) or Terminal (Mac), run:<br/>
#             <code>conda env update --f environment.yml --prune</code><br/>
#             Or if you used virtualenv rather than Anaconda, then run this from your activated environment in a Powershell (PC) or Terminal (Mac):<br/>
#             <code>pip install -r requirements.txt</code>
#             <br/>Then restart the kernel (Kernel menu >> Restart Kernel and Clear Outputs Of All Cells) to pick up the changes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Just one import to start with!!

import modal

# %% [markdown]
# # Setting up the modal tokens
#
# The first time you run this, please uncomment the next line and execute it.
# This is the same as running `modal setup` from the command line. It connects with Modal and installs your tokens.
#
# ## Debugging some common problems on Windows
#
# If this command fails in the next cell, or if any of the modal commands with the `!` fail, please try running them directly on the command line in an activated environment (without the `!`)
#
# A student on Windows mentioned that on Windows, you might also need to run this command from a command prompt in an activated environment afterwards:
# `modal token new`
# (Thank you Ed B. for that!)
#
# Another Windows student Minh N. mentioned you may need to use this approach, from an activated environment in the command line:
# `modal token set --token-id <your_token_id> --token-secret <your_token_secret>`
#
# Also, a student David S. mentioned the following:
# > In case anyone else using Windows hits this problem: Along with having to run `modal token new` from a command prompt, you have to move the generated token file. It will deploy the token file (.modal.toml) to your Windows profile folder. The virtual environment couldn't see that location (strangely, it couldn't even after I set environment variables for it and rebooted). I moved that token file to the folder I'm operating out of for the lab and it stopped throwing auth errors.
#
# And another Windows student (Robert M. - thank you!!) added another possible step:
#
#
# > I could not get modal to see my tokens (resulting in an 'auth error'), even after copying the ".modal.toml" file to the "week8" folder and restarting JupyterLab. The fix was to manually set the environment variables (the standard way). This config method is explained by modal on their [web site](https://modal.com/docs/reference/modal.config)
# ```
# import os
# os.environ["MODAL_TOKEN_ID"] = "xxx"
# os.environ["MODAL_TOKEN_SECRET"] = "yyy"
# ```
#
# Finally: I've also heard that in some situations, you might need to restart the Kernel of this jupyter notebook after running this. (Kernel menu >> Restart Kernel and Clear Outputs of All Cells).

# %%
# Remove the '# ' from the next line and run the cell, or run this command without the excalamation mark from an activated command prompt
# !modal setup
# Out:
# The web browser should have opened for you to authenticate and get an API token.
# If it didn't, please copy this URL into your web browser manually:
#
# ]8;id=882807;https://modal.com/token-flow/tf-OcYL5rbo0rPduvbhae0PFG\https://modal.com/token-flow/tf-OcYL5rbo0rPduvbhae0PFG]8;;\
#
# ⠋ Waiting for authentication in the web browser
# ⠏ Waiting for token flow to complete...omplete...
# Web authentication finished successfully!
# Token is connected to the kervin5 workspace.
# Verifying token against https://api.modal.com
# Token verified successfully!
# ⠋ Storing token
# Token written to /Users/kervin/.modal.toml in profile kervin5.

# %%
from hello import app, hello, hello_europe

# %%
with app.run():
    reply=hello.local()
reply
# Out:
# 'Hello from Hidden Hills, California, US!!'

# %%
with app.run():
    reply=hello.remote()
reply
# Out:
# 'Hello from Ashburn, Virginia, US!!'

# %% [markdown]
# ## Added thanks to student Tue H.
#
# If you look in hello.py, I've added a simple function hello_europe
#
# That uses the decorator:
# `@app.function(image=image, region="eu")`
#
# See the result below! More region specific settings are [here](https://modal.com/docs/guide/region-selection)
#
# Note that it does consume marginally more credits to specify a region.

# %%
with app.run():
    reply=hello_europe.remote()
reply
# Out:
# 'Hello from Paris, Île-de-France, FR!!'

# %% [markdown]
# # Before we move on -
#
# ## We need to set your HuggingFace Token as a secret in Modal
#
# 1. Go to modal.com, sign in and go to your dashboard
# 2. Click on Secrets in the nav bar
# 3. Create new secret, click on Hugging Face, this new secret needs to be called **hf-secret** because that's how we refer to it in the code
# 4. Fill in your HF_TOKEN where it prompts you
#
# ### And now back to business: time to work with Llama

# %%
# This import may give a deprecation warning about adding local Python modules to the Image
# That warning can be safely ignored. You may get the same warning in other places, too..

from llama import app, generate

# %%
with modal.enable_output():
    with app.run():
        result=generate.remote("Life is a mystery, everyone must stand alone, I hear")
result
# Out:
# Output()
# ✓ Initialized. View run at https://modal.com/apps/kervin5/main/ap-tgNcc6a5KbpolHWQ23StGH
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# Building image im-wBmKtmz1j1i6XhBcNS0CcR
# => Step 0: FROM base
# => Step 1: RUN python -m pip install accelerate bitsandbytes torch transformers
# Looking in indexes: http://pypi-mirror.modal.local:5555/simple
# Collecting accelerate
#   Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.9.0-py3-none-any.whl.metadata (19 kB)
# Collecting bitsandbytes
#   Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.46.1-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Collecting torch
#   Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.7.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Collecting transformers
#   Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.53.3-py3-none-any.whl.metadata (40 kB)
# Collecting numpy<3.0.0,>=1.17 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.3.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting packaging>=20.0 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting psutil (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting pyyaml (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting huggingface_hub>=0.21.0 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.33.4-py3-none-any.whl.metadata (14 kB)
# Collecting safetensors>=0.4.3 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting filelock (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/site-packages (from torch) (4.12.2)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2025.7.0-py3-none-any.whl.metadata (12 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparselt-cu12/nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.26.2 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufile-cu12/nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.3.1 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.3.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.11/site-packages (from triton==3.3.1->torch) (65.5.1)
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# Collecting requests (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting tokenizers<0.22,>=0.21 (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting tqdm>=4.27 (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting hf-xet<2.0.0,>=1.1.2 (from huggingface_hub>=0.21.0->accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/hf-xet/hf_xet-1.1.5-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (879 bytes)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting charset_normalizer<4,>=2 (from requests->transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests->transformers) (3.10)
# Collecting urllib3<3,>=1.21.1 (from requests->transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests->transformers) (2024.8.30)
# Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.9.0-py3-none-any.whl (367 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.46.1-py3-none-manylinux_2_24_x86_64.whl (72.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 164.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.7.1-cp311-cp311-manylinux_2_28_x86_64.whl (821.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.2/821.2 MB 379.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 386.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 393.0 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 394.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 532.0 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 383.9 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 372.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufile-cu12/nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 546.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 405.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 MB 387.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 MB 357.6 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparselt-cu12/nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 MB 350.4 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 382.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 307.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.3.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.7/155.7 MB 378.4 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.53.3-py3-none-any.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 328.1 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.33.4-py3-none-any.whl (515 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2025.7.0-py3-none-any.whl (199 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.3.1-cp311-cp311-manylinux_2_28_x86_64.whl (16.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 385.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-25.0-py3-none-any.whl (66 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (762 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.0/763.0 kB 540.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (792 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 792.7/792.7 kB 559.9 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (471 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 289.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 340.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.5-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 340.4 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (277 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.4-py3-none-any.whl (64 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (147 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/hf-xet/hf_xet-1.1.5-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 486.3 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 504.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.5.0-py3-none-any.whl (129 kB)
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, urllib3, triton, tqdm, sympy, safetensors, regex, pyyaml, psutil, packaging, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, hf-xet, fsspec, filelock, charset_normalizer, requests, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, huggingface_hub, torch, tokenizers, transformers, bitsandbytes, accelerate
# Successfully installed MarkupSafe-3.0.2 accelerate-1.9.0 bitsandbytes-0.46.1 charset_normalizer-3.4.2 filelock-3.18.0 fsspec-2025.7.0 hf-xet-1.1.5 huggingface_hub-0.33.4 jinja2-3.1.6 mpmath-1.3.0 networkx-3.5 numpy-2.3.1 nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-cufile-cu12-1.11.1.6 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 packaging-25.0 psutil-7.0.0 pyyaml-6.0.2 regex-2024.11.6 requests-2.32.4 safetensors-0.5.3 sympy-1.14.0 tokenizers-0.21.2 torch-2.7.1 tqdm-4.67.1 transformers-4.53.3 triton-3.3.1 urllib3-2.5.0
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Saving image...
# Image saved, took 7.80s
# Built image im-wBmKtmz1j1i6XhBcNS0CcR in 76.10s
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ✓ Created objects.
# ├── 🔨 Created mount /Users/kervin/Coding/learning/llm/llm_engineering/week8/llama.py
# └── 🔨 Created function generate.
# Output()
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Fetching 4 files:  25%|██▌       | 1/4 [01:28<04:26, 88.73s/it]Fetching 4 files: 100%|██████████| 4/4 [01:28<00:00, 22.18s/it]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:05<00:15,  5.01s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:10<00:10,  5.32s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:15<00:05,  5.20s/it]Loading checkpoint shards: 100%|██████████| 4/4 [00:16<00:00,  3.31s/it]Loading checkpoint shards: 100%|██████████| 4/4 [00:16<00:00,  4.00s/it]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Stopping app - local entrypoint completed.
# ✓ App completed. View run at https://modal.com/apps/kervin5/main/ap-tgNcc6a5KbpolHWQ23StGH
# '<|begin_of_text|>Life is a mystery, everyone must stand alone, I hear you call my name,'

# %%
import modal
from pricer_ephemeral import app, price

# %%
with modal.enable_output():
    with app.run():
        result=price.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
result
# Out:
# Output()
# ✓ Initialized. View run at https://modal.com/apps/kervin5/main/ap-2MwN9I7tcqGAzIZlhKLW7k
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# Building image im-cdsN2lH27PUJEuBriejMIb
# => Step 0: FROM base
# => Step 1: RUN python -m pip install accelerate bitsandbytes peft torch transformers
# Looking in indexes: http://pypi-mirror.modal.local:5555/simple
# Collecting accelerate
#   Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.9.0-py3-none-any.whl.metadata (19 kB)
# Collecting bitsandbytes
#   Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.46.1-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Collecting peft
#   Downloading http://pypi-mirror.modal.local:5555/simple/peft/peft-0.16.0-py3-none-any.whl.metadata (14 kB)
# Collecting torch
#   Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.7.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Collecting transformers
#   Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.53.3-py3-none-any.whl.metadata (40 kB)
# Collecting numpy<3.0.0,>=1.17 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.3.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting packaging>=20.0 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting psutil (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting pyyaml (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting huggingface_hub>=0.21.0 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.33.4-py3-none-any.whl.metadata (14 kB)
# Collecting safetensors>=0.4.3 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting tqdm (from peft)
#   Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting filelock (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/site-packages (from torch) (4.12.2)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2025.7.0-py3-none-any.whl.metadata (12 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparselt-cu12/nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.26.2 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufile-cu12/nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.3.1 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.3.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.11/site-packages (from triton==3.3.1->torch) (65.5.1)
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# Collecting requests (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting tokenizers<0.22,>=0.21 (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting hf-xet<2.0.0,>=1.1.2 (from huggingface_hub>=0.21.0->accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/hf-xet/hf_xet-1.1.5-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (879 bytes)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting charset_normalizer<4,>=2 (from requests->transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests->transformers) (3.10)
# Collecting urllib3<3,>=1.21.1 (from requests->transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests->transformers) (2024.8.30)
# Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.9.0-py3-none-any.whl (367 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.46.1-py3-none-manylinux_2_24_x86_64.whl (72.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 196.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/peft/peft-0.16.0-py3-none-any.whl (472 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.7.1-cp311-cp311-manylinux_2_28_x86_64.whl (821.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.2/821.2 MB 192.3 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 192.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 182.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 212.3 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 181.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 204.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 206.1 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufile-cu12/nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 339.5 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 185.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 MB 180.6 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 MB 204.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparselt-cu12/nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 MB 190.1 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 207.5 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 191.9 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.3.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.7/155.7 MB 173.3 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.53.3-py3-none-any.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 201.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.33.4-py3-none-any.whl (515 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2025.7.0-py3-none-any.whl (199 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.3.1-cp311-cp311-manylinux_2_28_x86_64.whl (16.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 370.9 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-25.0-py3-none-any.whl (66 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (762 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.0/763.0 kB 355.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (792 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 792.7/792.7 kB 241.3 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (471 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 304.1 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 224.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.5-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 365.1 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (277 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.4-py3-none-any.whl (64 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (147 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/hf-xet/hf_xet-1.1.5-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 159.3 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, urllib3, triton, tqdm, sympy, safetensors, regex, pyyaml, psutil, packaging, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, hf-xet, fsspec, filelock, charset_normalizer, requests, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, huggingface_hub, torch, tokenizers, transformers, bitsandbytes, accelerate, peft
# Successfully installed MarkupSafe-3.0.2 accelerate-1.9.0 bitsandbytes-0.46.1 charset_normalizer-3.4.2 filelock-3.18.0 fsspec-2025.7.0 hf-xet-1.1.5 huggingface_hub-0.33.4 jinja2-3.1.6 mpmath-1.3.0 networkx-3.5 numpy-2.3.1 nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-cufile-cu12-1.11.1.6 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 packaging-25.0 peft-0.16.0 psutil-7.0.0 pyyaml-6.0.2 regex-2024.11.6 requests-2.32.4 safetensors-0.5.3 sympy-1.14.0 tokenizers-0.21.2 torch-2.7.1 tqdm-4.67.1 transformers-4.53.3 triton-3.3.1 urllib3-2.5.0
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Saving image...
# Image saved, took 8.97s
# Built image im-cdsN2lH27PUJEuBriejMIb in 110.09s
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ✓ Created objects.
# ├── 🔨 Created mount /Users/kervin/Coding/learning/llm/llm_engineering/week8/pricer_ephemeral.py
# └── 🔨 Created function price.
# Output()
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Fetching 4 files:  25%|██▌       | 1/4 [01:16<03:50, 76.75s/it]Fetching 4 files:  50%|█████     | 2/4 [01:21<01:08, 34.35s/it]Fetching 4 files: 100%|██████████| 4/4 [01:21<00:00, 20.36s/it]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:04<00:14,  4.90s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:10<00:10,  5.20s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:17<00:05,  5.91s/it]Loading checkpoint shards: 100%|██████████| 4/4 [00:17<00:00,  3.79s/it]Loading checkpoint shards: 100%|██████████| 4/4 [00:17<00:00,  4.40s/it]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Stopping app - local entrypoint completed.
# ✓ App completed. View run at https://modal.com/apps/kervin5/main/ap-2MwN9I7tcqGAzIZlhKLW7k
# 133.0

# %% [markdown]
# ## Transitioning From Ephemeral Apps to Deployed Apps
#
# From a command line, `modal deploy xxx` will deploy your code as a Deployed App
#
# This is how you could package your AI service behind an API to be used in a Production System.
#
# You can also build REST endpoints easily, although we won't cover that as we'll be calling direct from Python.
#
# ## Important note about secrets
#
# In both the files `pricer_service.py` and `pricer_service2.py` you will find code like this near the top:
# `secrets = [modal.Secret.from_name("hf-secret")]`
# You may need to change from `hf-secret` to `huggingface-secret` depending on how the Secret is configured in modal.
# To check, visit this page and look in the first column:
# https://modal.com/secrets/
#
# ## Important note for Windows people:
#
# On the next line, I call `modal deploy` from within Jupyter lab; I've heard that on some versions of Windows this gives a strange unicode error because modal prints emojis to the output which can't be displayed. If that happens to you, simply use an Anaconda Prompt window or a Powershell instead, with your environment activated, and type `modal deploy pricer_service` there. Follow the same approach the next time we do `!modal deploy` too.
#
# As an alternative, a few students have mentioned you can run this code within Jupyter Lab if you want to run it from here:
# ```
# # Check the default encoding
# print(locale.getpreferredencoding())  # Should print 'UTF-8'
#
# # Ensure UTF-8 encoding
# os.environ['PYTHONIOENCODING'] = 'utf-8'
# ```

# %%
# You can also run "modal deploy -m pricer_service" at the command line in an activated environment
# !modal deploy -m pricer_service
# Out:
# ⠸ Creating objects.....
# └── ⠋ Creating mount
#     /Users/kervin/Coding/learning/llm/llm_engineering/week8/pricer_service.py:
# ⠦ Creating objects...
# ├── 🔨 Created mount
# │   /Users/kervin/Coding/learning/llm/llm_engineering/week8/pricer_service.py
# ⠧ Creating objects...
# ├── 🔨 Created mount
# │   /Users/kervin/Coding/learning/llm/llm_engineering/week8/pricer_service.py
# └── 🔨 Created function price.
# ✓ Created objects.
# ├── 🔨 Created mount
# │   /Users/kervin/Coding/learning/llm/llm_engineering/week8/pricer_service.py
# └── 🔨 Created function price.
# ✓ App deployed in 1.201s! 🎉
#
# View Deployment: https://modal.com/apps/kervin5/main/deployed/pricer-service

# %%
pricer = modal.Function.from_name("pricer-service", "price")

# %%
# This can take a while! We'll use faster approaches shortly

pricer.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
# Out:
# 133.0

# %%
# You can also run "modal deploy -m pricer_service2" at the command line in an activated environment

# !modal deploy -m pricer_service2
# Out:
# ⠸ Creating objects.....
# └── ⠋ Creating mount
#     /Users/kervin/Coding/learning/llm/llm_engineering/week8/pricer_service2.py:
# ⠦ Creating objects...
# └── 🔨 Created mount
# Building image im-TuaJxNesbd4Jr6DMoGYAAdek8/pricer_service2.py
# ⠦ Creating objects...
# 🔨 Created mount /Users/kervin/Coding/learning/llm/llm_engineering/week8/pri
# => Step 0: FROM base
# ⠇ Creating objects...
# 🔨 Created mount /Users/kervin/Coding/learning/llm/llm_engineering/week8/pri
# => Step 1: RUN python -m pip install accelerate bitsandbytes huggingface peft torch transformers
# ⠇ Creating objects...
# ⠏ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# Looking in indexes: http://pypi-mirror.modal.local:5555/simple
# ⠋ Creating objects...
# Collecting accelerate /Users/kervin/Coding/learning/llm/llm_engineering/week8/pri
# ⠋ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.9.0-py3-none-any.whl.metadata (19 kB)
# ⠙ Creating objects...
# Collecting bitsandbytesUsers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# ⠙ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.46.1-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# ⠹ Creating objects...
# Collecting huggingface/Users/kervin/Coding/learning/llm/llm_engineering/week8/pri
# ⠹ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/huggingface/huggingface-0.0.1-py3-none-any.whl.metadata (2.9 kB)
# ⠹ Creating objects...
# Collecting peft mount /Users/kervin/Coding/learning/llm/llm_engineering/week8/pri
# ⠹ Creating objects...
# ⠹ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
#   Downloading http://pypi-mirror.modal.local:5555/simple/peft/peft-0.16.0-py3-none-any.whl.metadata (14 kB)
# ⠹ Creating objects...
# Collecting torchmount /Users/kervin/Coding/learning/llm/llm_engineering/week8/pri
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.7.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (29 kB)
# ⠸ Creating objects...
# Collecting transformersUsers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# ⠼ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.53.3-py3-none-any.whl.metadata (40 kB)
# ⠼ Creating objects...
# ⠴ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# Collecting numpy<3.0.0,>=1.17 (from accelerate)cer_service2.py
# ⠏ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.3.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (62 kB)
# ⠋ Creating objects...
# Collecting packaging>=20.0 (from accelerate)earning/llm/llm_engineering/week8/pri
# ⠋ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# ⠋ Creating objects...
# ⠙ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
# Collecting psutil (from accelerate)ng/week8/pricer_service2.py
# ⠙ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# ⠹ Creating objects...
# Collecting pyyaml (from accelerate)/Coding/learning/llm/llm_engineering/week8/pri
# ⠹ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# ⠹ Creating objects...
# Collecting huggingface_hub>=0.21.0 (from accelerate)llm/llm_engineering/week8/pri
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.33.4-py3-none-any.whl.metadata (14 kB)
# ⠸ Creating objects...
# ⠼ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
# Collecting safetensors>=0.4.3 (from accelerate)cer_service2.py
# ⠦ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# ⠦ Creating objects...
# Collecting tqdm (from peft)s/kervin/Coding/learning/llm/llm_engineering/week8/pri
# ⠧ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ⠧ Creating objects...
# ⠇ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
# Collecting filelock (from torch)ering/week8/pricer_service2.py
# ⠇ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/site-packages (from torch) (4.12.2)
# ⠇ Creating objects...
# Collecting sympy>=1.13.3 (from torch)oding/learning/llm/llm_engineering/week8/pri
# ⠏ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# ⠏ Creating objects...
# Collecting networkx (from torch)vin/Coding/learning/llm/llm_engineering/week8/pri
# ⠏ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# ⠏ Creating objects...
# Collecting jinja2 (from torch)ervin/Coding/learning/llm/llm_engineering/week8/pri
# ⠋ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# ⠋ Creating objects...
# Collecting fsspec (from torch)ervin/Coding/learning/llm/llm_engineering/week8/pri
# ⠋ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2025.7.0-py3-none-any.whl.metadata (12 kB)
# ⠋ Creating objects...
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch)/llm_engineering/week8/pri
# ⠙ Creating objects...
# ⠙ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ⠙ Creating objects...
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch)lm_engineering/week8/pri
# ⠙ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# ⠙ Creating objects...
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch)/llm_engineering/week8/pri
# ⠹ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# ⠹ Creating objects...
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch)/llm/llm_engineering/week8/pri
# ⠹ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# ⠹ Creating objects...
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch)llm/llm_engineering/week8/pri
# ⠹ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# ⠹ Creating objects...
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch)/llm/llm_engineering/week8/pri
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# ⠸ Creating objects...
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch)lm/llm_engineering/week8/pri
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# ⠸ Creating objects...
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch)m/llm_engineering/week8/pri
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# ⠸ Creating objects...
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch)m/llm_engineering/week8/pri
# ⠼ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# ⠼ Creating objects...
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch)lm/llm_engineering/week8/pri
# ⠼ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparselt-cu12/nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# ⠼ Creating objects...
# ⠼ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
# Collecting nvidia-nccl-cu12==2.26.2 (from torch)er_service2.py
# ⠼ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# ⠼ Creating objects...
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch)ng/llm/llm_engineering/week8/pri
# ⠼ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# ⠴ Creating objects...
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch)m/llm_engineering/week8/pri
# ⠴ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# ⠴ Creating objects...
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch)llm/llm_engineering/week8/pri
# ⠴ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufile-cu12/nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# ⠴ Creating objects...
# Collecting triton==3.3.1 (from torch)oding/learning/llm/llm_engineering/week8/pri
# ⠴ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.3.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# ⠴ Creating objects...
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.11/site-packages (from triton==3.3.1->torch) (65.5.1)
# ⠦ Creating objects...
# ⠧ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# Collecting regex!=2019.12.17 (from transformers)er_service2.py
# ⠹ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# ⠹ Creating objects...
# Collecting requests (from transformers)ing/learning/llm/llm_engineering/week8/pri
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# ⠸ Creating objects...
# ⠸ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
# Collecting tokenizers<0.22,>=0.21 (from transformers)rvice2.py
# ⠴ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# ⠦ Creating objects...
# ⠧ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
# Collecting hf-xet<2.0.0,>=1.1.2 (from huggingface_hub>=0.21.0->accelerate)
# ⠧ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/hf-xet/hf_xet-1.1.5-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (879 bytes)
# ⠧ Creating objects...
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)lm_engineering/week8/pri
# ⠧ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# ⠧ Creating objects...
# Collecting MarkupSafe>=2.0 (from jinja2->torch)ning/llm/llm_engineering/week8/pri
# ⠇ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# ⠇ Creating objects...
# Collecting charset_normalizer<4,>=2 (from requests->transformers)eering/week8/pri
# ⠋ Creating objects...
# ⠋ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
#   Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests->transformers) (3.10)
# ⠋ Creating objects...
# Collecting urllib3<3,>=1.21.1 (from requests->transformers)_engineering/week8/pri
# ⠙ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests->transformers) (2024.8.30)
# ⠙ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.9.0-py3-none-any.whl (367 kB)
# ⠙ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.46.1-py3-none-manylinux_2_24_x86_64.whl (72.9 MB)
# ⠙ Creating objects...
# ⠸ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 295.3 MB/s eta 0:00:00
# ⠼ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/huggingface/huggingface-0.0.1-py3-none-any.whl (2.5 kB)
# ⠴ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/peft/peft-0.16.0-py3-none-any.whl (472 kB)
# ⠴ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.7.1-cp311-cp311-manylinux_2_28_x86_64.whl (821.2 MB)
# ⠴ Creating objects...
# ⠦ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.2/821.2 MB 240.5 MB/s eta 0:00:00
# ⠴ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
# ⠦ Creating objects...
# ⠇ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 226.6 MB/s eta 0:00:00
# ⠋ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
# ⠋ Creating objects...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 205.4 MB/s eta 0:00:00/pri
# ⠋ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
# ⠋ Creating objects...
# ⠋ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 203.4 MB/s eta 0:00:00
# ⠙ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 316.9 MB/s eta 0:00:00
# ⠙ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
# ⠹ Creating objects...
# ⠸ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 254.0 MB/s eta 0:00:00
# ⠙ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
# ⠹ Creating objects...
# ⠹ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 237.7 MB/s eta 0:00:00
# ⠹ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufile-cu12/nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 498.4 MB/s eta 0:00:00
# ⠹ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
# ⠹ Creating objects...
# ⠼ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 257.0 MB/s eta 0:00:00
# ⠴ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
# ⠴ Creating objects...
# ⠇ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 MB 256.0 MB/s eta 0:00:00
# ⠸ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
# ⠸ Creating objects...
# ⠼ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 MB 271.9 MB/s eta 0:00:00
# ⠸ Creating objects...
# ⠸ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparselt-cu12/nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
# ⠼ Creating objects...
# ⠧ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 MB 235.9 MB/s eta 0:00:00
# ⠙ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
# ⠹ Creating objects...
# ⠸ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 257.5 MB/s eta 0:00:00
# ⠙ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
# ⠹ Creating objects...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 274.7 MB/s eta 0:00:00ri
# ⠹ Creating objects...
# ⠹ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# ⠸ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.3.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.7 MB)
# ⠸ Creating objects...
# ⠦ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.7/155.7 MB 176.5 MB/s eta 0:00:00
# ⠼ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.53.3-py3-none-any.whl (10.8 MB)
# ⠼ Creating objects...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 302.3 MB/s eta 0:00:00ri
# ⠴ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.33.4-py3-none-any.whl (515 kB)
# ⠴ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2025.7.0-py3-none-any.whl (199 kB)
# ⠴ Creating objects...
# ⠴ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
# Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.3.1-cp311-cp311-manylinux_2_28_x86_64.whl (16.9 MB)
# ⠴ Creating objects...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 184.3 MB/s eta 0:00:00ri
# ⠦ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-25.0-py3-none-any.whl (66 kB)
# ⠦ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (762 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.0/763.0 kB 361.1 MB/s eta 0:00:00
# ⠦ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (792 kB)
# ⠧ Creating objects...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 792.7/792.7 kB 144.3 MB/s eta 0:00:00i
# ⠧ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (471 kB)
# ⠧ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.14.0-py3-none-any.whl (6.3 MB)
# ⠧ Creating objects...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 294.0 MB/s eta 0:00:00/pri
# ⠧ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
# ⠧ Creating objects...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 329.7 MB/s eta 0:00:00/pri
# ⠇ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl (78 kB)
# ⠇ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.18.0-py3-none-any.whl (16 kB)
# ⠇ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.6-py3-none-any.whl (134 kB)
# ⠇ Creating objects...
# ⠇ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
# Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.5-py3-none-any.whl (2.0 MB)
# ⠏ Creating objects...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 234.2 MB/s eta 0:00:00/pri
# ⠏ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (277 kB)
# ⠏ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.4-py3-none-any.whl (64 kB)
# ⠏ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (147 kB)
# ⠏ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/hf-xet/hf_xet-1.1.5-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
# ⠏ Creating objects...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 296.0 MB/s eta 0:00:00/pri
# ⠏ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# ⠏ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 420.1 MB/s eta 0:00:00
# ⠋ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.5.0-py3-none-any.whl (129 kB)
# ⠋ Creating objects...
# ⠙ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, huggingface, urllib3, triton, tqdm, sympy, safetensors, regex, pyyaml, psutil, packaging, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, hf-xet, fsspec, filelock, charset_normalizer, requests, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, huggingface_hub, torch, tokenizers, transformers, bitsandbytes, accelerate, peft
# ⠋ Creating objects...
# ⠸ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# Successfully installed MarkupSafe-3.0.2 accelerate-1.9.0 bitsandbytes-0.46.1 charset_normalizer-3.4.2 filelock-3.18.0 fsspec-2025.7.0 hf-xet-1.1.5 huggingface-0.0.1 huggingface_hub-0.33.4 jinja2-3.1.6 mpmath-1.3.0 networkx-3.5 numpy-2.3.1 nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-cufile-cu12-1.11.1.6 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 packaging-25.0 peft-0.16.0 psutil-7.0.0 pyyaml-6.0.2 regex-2024.11.6 requests-2.32.4 safetensors-0.5.3 sympy-1.14.0 tokenizers-0.21.2 torch-2.7.1 tqdm-4.67.1 transformers-4.53.3 triton-3.3.1 urllib3-2.5.0
# ⠧ Creating objects...
# 🔨 Created mount /Users/kervin/Coding/learning/llm/llm_engineering/week8/pri
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# ⠧ Creating objects...
# ⠏ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# Saving image...ng/llm/llm_engineering/week8/pricer_service2.py
# ⠙ Creating objects...
# ⠼ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━ 3.0/5.8 GB 0:00:00
# ⠼ Creating objects...
# └── 🔨 Created mount
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━ 3.0/5.8 GB 0:00:00
# ⠧ Creating objects...
# └── 🔨 Created mount
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━ 3.3/5.8 GB 0:00:00
# ⠋ Creating objects...
# └── 🔨 Created mount
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━ 3.7/5.8 GB 0:00:00
# ⠸ Creating objects...
# └── 🔨 Created mount
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━ 3.8/5.8 GB 0:00:01
# ⠦ Creating objects...
# └── 🔨 Created mount
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━ 3.9/5.8 GB 0:00:01
# ⠋ Creating objects...
# └── 🔨 Created mount
# ⠸ Creating objects...ring/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# Image saved, took 15.11sm_engineering/week8/pricer_service2.py
# ⠋ Creating objects...
# 🔨 Created mount /Users/kervin/Coding/learning/llm/llm_engineering/week8/pri
# Built image im-TuaJxNesbd4Jr6DMoGYAAd in 110.75s
#
#
# ⠙ Creating objects...
# ⠙ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# Building image im-BtwGVkL3gpEIbGyjP5yBHRek8/pricer_service2.py
# ⠹ Creating objects...
# ⠼ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
# ⠧ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# n/Coding/learning/llm/llm_engineering/week8/pricer_service2.py
# => Step 0: FROM base
# ⠧ Creating objects...
# 🔨 Created mount /Users/kervin/Coding/learning/llm/llm_engineering/week8/pri
# => Step 1: ENV HF_HUB_CACHE=/cache
# ⠧ Creating objects...
# ⠋ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
# ⠸ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# └── 🔨 Created mount
# Saving image...ng/llm/llm_engineering/week8/pricer_service2.py
# ⠇ Creating objects...
# ⠏ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
# Image saved, took 551.89msengineering/week8/pricer_service2.py
# ⠹ Creating objects...
# 🔨 Created mount /Users/kervin/Coding/learning/llm/llm_engineering/week8/pri
# Built image im-BtwGVkL3gpEIbGyjP5yBHR in 1.60s
#
#
# ⠹ Creating objects...
# ⠸ Creating objects...ers/kervin/Coding/learning/llm/llm_engineering/week8/pri
# └── 🔨 Created mount
# ⠦ Creating objects..._engineering/week8/pricer_service2.py
# ├── 🔨 Created mount
# │   /Users/kervin/Coding/learning/llm/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects...
# ├── 🔨 Created mount
# │   /Users/kervin/Coding/learning/llm/llm_engineering/week8/pricer_service2.py
# └── 🔨 Created function Pricer.*.
# ✓ Created objects.
# ├── 🔨 Created mount
# │   /Users/kervin/Coding/learning/llm/llm_engineering/week8/pricer_service2.py
# └── 🔨 Created function Pricer.*.
# ✓ App deployed in 115.481s! 🎉
#
# View Deployment: https://modal.com/apps/kervin5/main/deployed/pricer-service

# %%
Pricer = modal.Cls.from_name("pricer-service", "Pricer")
pricer = Pricer()
reply = pricer.price.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
print(reply)
# Out:
# 133.0

# %% [markdown]
# # Optional: Keeping Modal warm
#
# ## A way to improve the speed of the Modal pricer service
#
# The first time you run this modal class, it might take as much as 10 minutes to build.
# Subsequently it should be much faster.. 30 seconds if it needs to wake up, otherwise 2 seconds.
# If you want it to always be 2 seconds, you can keep the container from going to sleep by editing this constant in pricer_service2.py:
#
# `MIN_CONTAINERS = 0`
#
# Make it 1 to keep a container alive.
# But please note: this will eat up credits! Only do this if you are comfortable to have a process running continually.

# %% [markdown]
# ## And now introducing our Agent class

# %%
from agents.specialist_agent import SpecialistAgent

# %%
agent = SpecialistAgent()
agent.price("iPad Pro 2nd generation")
# Out:
# 299.0
